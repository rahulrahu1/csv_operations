# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd# data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/bricseconomicindicatorsdatasetprediction/bricseconomicindicatorsdatasetprediction.csv

# %%
pd.read_csv("/kaggle/input/bricseconomicindicatorsdatasetprediction/bricseconomicindicatorsdatasetprediction.csv")
# Out:
#                                             SeriesName      SeriesCode  \
# 0    General government final consumption expenditu...  NE.CON.GOVT.ZS
# 1    General government final consumption expenditu...  NE.CON.GOVT.ZS
# 2    General government final consumption expenditu...  NE.CON.GOVT.ZS
# 3    General government final consumption expenditu...  NE.CON.GOVT.ZS
# 4    General government final consumption expenditu...  NE.CON.GOVT.ZS
# ..                                                 ...             ...
# 245  General government final consumption expenditu...  NE.CON.GOVT.ZS
# 246  General government final consumption expenditu...  NE.CON.GOVT.ZS
# 247  General government final consumption expenditu...  NE.CON.GOVT.ZS
# 248  General government final consumption expenditu...  NE.CON.GOVT.ZS
# 249  General government final consumption expenditu...  NE.CON.GOVT.ZS
#
#             CountryName CountryCode    Year      Value  CountryCode_encoded  \
# ...

# %%
df = pd.read_csv('/kaggle/input/bricseconomicindicatorsdatasetprediction/bricseconomicindicatorsdatasetprediction.csv')
print(df)
# Out:
#                                             SeriesName      SeriesCode  \
# 0    General government final consumption expenditu...  NE.CON.GOVT.ZS
# 1    General government final consumption expenditu...  NE.CON.GOVT.ZS
# 2    General government final consumption expenditu...  NE.CON.GOVT.ZS
# 3    General government final consumption expenditu...  NE.CON.GOVT.ZS
# 4    General government final consumption expenditu...  NE.CON.GOVT.ZS
# ..                                                 ...             ...
# 245  General government final consumption expenditu...  NE.CON.GOVT.ZS
# 246  General government final consumption expenditu...  NE.CON.GOVT.ZS
# 247  General government final consumption expenditu...  NE.CON.GOVT.ZS
# 248  General government final consumption expenditu...  NE.CON.GOVT.ZS
# 249  General government final consumption expenditu...  NE.CON.GOVT.ZS
#
#             CountryName CountryCode    Year      Value  CountryCode_encoded  \
# ...

# %%
df.head()
# Out:
#                                           SeriesName      SeriesCode  \
# 0  General government final consumption expenditu...  NE.CON.GOVT.ZS
# 1  General government final consumption expenditu...  NE.CON.GOVT.ZS
# 2  General government final consumption expenditu...  NE.CON.GOVT.ZS
# 3  General government final consumption expenditu...  NE.CON.GOVT.ZS
# 4  General government final consumption expenditu...  NE.CON.GOVT.ZS
#
#           CountryName CountryCode    Year      Value  CountryCode_encoded  \
# 0              Brazil         BRA  1970.0  11.324653                    0
# 1               China         CHN  1970.0  10.961783                    1
# 2               India         IND  1970.0   8.947244                    2
# 3  Russian Federation         RUS  1970.0  11.396583                    3
# 4        South Africa         ZAF  1970.0  11.903314                    4
#
#    SeriesCode_encoded  Predictions  Absolute_Error
# 0                   0    10.775955        0.548698
# ...

# %%
df.tail()
# Out:
#                                             SeriesName      SeriesCode  \
# 245  General government final consumption expenditu...  NE.CON.GOVT.ZS
# 246  General government final consumption expenditu...  NE.CON.GOVT.ZS
# 247  General government final consumption expenditu...  NE.CON.GOVT.ZS
# 248  General government final consumption expenditu...  NE.CON.GOVT.ZS
# 249  General government final consumption expenditu...  NE.CON.GOVT.ZS
#
#             CountryName CountryCode    Year      Value  CountryCode_encoded  \
# 245              Brazil         BRA  2019.0  20.282566                    0
# 246               China         CHN  2019.0  16.838430                    1
# 247               India         IND  2019.0  11.767826                    2
# 248  Russian Federation         RUS  2019.0  18.302966                    3
# 249        South Africa         ZAF  2019.0  21.295737                    4
#
#      SeriesCode_encoded  Predictions  Absolute_Error
# ...

# %%
data = df.info()
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SeriesName           250 non-null    object
#  1   SeriesCode           250 non-null    object
#  2   CountryName          250 non-null    object
#  3   CountryCode          250 non-null    object
#  4   Year                 250 non-null    float64
#  5   Value                250 non-null    float64
#  6   CountryCode_encoded  250 non-null    int64
#  7   SeriesCode_encoded   250 non-null    int64
#  8   Predictions          250 non-null    float64
#  9   Absolute_Error       250 non-null    float64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 19.7+ KB

# %%
data = df.describe()
data
# Out:
#               Year       Value  CountryCode_encoded  SeriesCode_encoded  \
# count   250.000000  250.000000           250.000000               250.0
# mean   1994.500000   14.820536             2.000000                 0.0
# std      14.459818    3.692582             1.417051                 0.0
# min    1970.000000    8.284794             0.000000                 0.0
# 25%    1982.000000   11.441486             1.000000                 0.0
# 50%    1994.500000   14.551656             2.000000                 0.0
# 75%    2007.000000   18.467168             3.000000                 0.0
# max    2019.000000   21.295737             4.000000                 0.0
#
#        Predictions  Absolute_Error
# count   250.000000      250.000000
# mean     14.893878        1.054706
# std       3.204639        0.915081
# min       9.534234        0.010852
# 25%      12.233185        0.351689
# 50%      14.314545        0.790441
# 75%      17.426470        1.530678
# ...

# %%
data = df.shape
data
# Out:
# (250, 10)

# %%
df.sample()
# Out:
#                                             SeriesName      SeriesCode  \
# 169  General government final consumption expenditu...  NE.CON.GOVT.ZS
#
#       CountryName CountryCode    Year      Value  CountryCode_encoded  \
# 169  South Africa         ZAF  2003.0  19.057888                    4
#
#      SeriesCode_encoded  Predictions  Absolute_Error
# 169                   0    19.404324        0.346436

# %%
data = sns.scatterplot(df['Predictions'],)
datanw = data = sns.scatterplot(df['Absolute_Error'],)
data,datanw
# Out:
# (<Axes: ylabel='Predictions'>, <Axes: ylabel='Predictions'>)

# %%
import matplotlib.pyplot as plt
data = plt.hist(df['Predictions'])
dataa = plt.hist(df['Absolute_Error'])
data,dataa
# Out:
# ((array([22., 33., 45., 32., 22., 20., 24., 32., 17.,  3.]),
#   array([ 9.53423444, 10.79561911, 12.05700378, 13.31838846, 14.57977313,
#          15.84115781, 17.10254248, 18.36392716, 19.62531183, 20.88669651,
#          22.14808118]),
#   <BarContainer object of 10 artists>),
#  (array([86., 55., 42., 25., 20., 11.,  2.,  5.,  1.,  3.]),
#   array([0.01085242, 0.48323431, 0.9556162 , 1.42799809, 1.90037998,
#          2.37276188, 2.84514377, 3.31752566, 3.78990755, 4.26228944,
#          4.73467134]),
#   <BarContainer object of 10 artists>))
